# %% [markdown]
# # **Data Retrival**

# %%
#| label: cell-dataretrival
# Necessary imports
import json
from datetime import datetime, timedelta, timezone
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import xmltodict
import schedule
import time

# %% [markdown]
# ## **Getting Data from USGS Earthquake API**

# %%
#| label: cell-dataretrival1
#get data of Earthquakes from API
def fetch_data():
    response = requests.get("https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson")
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
    # Convert JSON response to a dictionary
        data = response.json()
    else:
        print(f"Failed to fetch data from API. Status code: {response.status_code}")
    return data

# %%
#| label: cell-dataretrival2
data = fetch_data()

# %%
#| label: cell-dataretrival3
data["features"][0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 1.1,
#   'place': '13 km N of Fishhook, Alaska',
#   'time': 1718302410679,
#   'updated': 1718302585284,
#   'tz': None,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0247l6gx1g',
#   'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0247l6gx1g&format=geojson',
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'alert': None,
#   'status': 'automatic',
#   'tsunami': 0,
#   'sig': 19,
#   'net': 'ak',
#   'code': '0247l6gx1g',
#   'ids': ',ak0247l6gx1g,',
#   'sources': ',ak,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': None,
#   'rms': 0.85,
#   'gap': None,
#   'magType': 'ml',
#   'type': 'earthquake',
#   'title': 'M 1.1 - 13 km N of Fishhook, Alaska'},
#  'geometry': {'type': 'Point', 'coordinates': [-149.2821, 61.8655, 180.4]},
#  'id': 'ak0247l6gx1g'}

# %%
#| label: cell-dataretrival4
# Extract desired information
generated = data['metadata']['generated']
url = data['metadata']['url']
title = data['metadata']['title']
count = data['metadata']['count']

# Print extracted information
print("Generated:", generated)
print("URL:", url)
print("Title:", title)
print("Count:", count)
# Out:
# Generated: 1718303157000
# URL: https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson
# Title: USGS Earthquakes
# Count: 10179

# %% [markdown]
# ## **Automate the data**

# %%
#| label: cell-dataretrival5
# Schedule the job to run at 11:58 PM UTC every day
schedule.every().day.at("23:58").do(fetch_data)

schedule.run_pending()

# %% [markdown]
# # **Raw data to Pandas DataFrame**

# %%
#| label: cell-datatopandas
df = pd.json_normalize(data['features'])
df
# Out:
#           type            id  properties.mag  \
# 0      Feature  ak0247l6gx1g            1.10
# 1      Feature    hv74275801            2.36
# 2      Feature    ci40797520            2.68
# 3      Feature  ak0247l63lv6            2.10
# 4      Feature  ak0247l63fcl            3.20
# ...        ...           ...             ...
# 10174  Feature    av93126556            1.56
# 10175  Feature    ci40582351            0.70
# 10176  Feature    hv74230877            1.60
# 10177  Feature    ok2024jmgh            1.11
# 10178  Feature    ok2024jmgf            1.67
#
#                            properties.place  properties.time  \
# 0               13 km N of Fishhook, Alaska    1718302410679
# 1                2 km WSW of Pāhala, Hawaii    1718302194290
# 2              12 km WSW of Delta, B.C., MX    1718301998380
# 3              73 km SE of Cantwell, Alaska    1718301080508
# 4                26 km W of Chenega, Alaska    1718301037287
# ...                                     ...              ...
# 10174         73 km WSW of Nikolski, Alaska    1715712228980
# 10175                    8 km N of Anza, CA    1715711994330
# 10176            5 km NNE of Pāhala, Hawaii    1715711873890
# 10177      3 km SSE of Mill Creek, Oklahoma    1715711839429
# 10178  2 km ESE of Rocky Mountain, Oklahoma    1715711761800
#
#        properties.updated properties.tz  \
# 0           1718302585284          None
# 1           1718302323380          None
# 2           1718302126916          None
# 3           1718301218013          None
# 4           1718302752417          None
# ...                   ...           ...
# 10174       1715817075320          None
# 10175       1715721874210          None
# 10176       1715736684390          None
# 10177       1715791212738          None
# 10178       1715718052630          None
#
#                                           properties.url  \
# 0      https://earthquake.usgs.gov/earthquakes/eventp...
# 1      https://earthquake.usgs.gov/earthquakes/eventp...
# 2      https://earthquake.usgs.gov/earthquakes/eventp...
# 3      https://earthquake.usgs.gov/earthquakes/eventp...
# 4      https://earthquake.usgs.gov/earthquakes/eventp...
# ...                                                  ...
# 10174  https://earthquake.usgs.gov/earthquakes/eventp...
# 10175  https://earthquake.usgs.gov/earthquakes/eventp...
# 10176  https://earthquake.usgs.gov/earthquakes/eventp...
# 10177  https://earthquake.usgs.gov/earthquakes/eventp...
# 10178  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                        properties.detail  properties.felt  \
# 0      https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 1      https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 2      https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 3      https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 4      https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# ...                                                  ...              ...
# 10174  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10175  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10176  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10177  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10178  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
#
#        ...                                   properties.types  properties.nst  \
# 0      ...                                ,origin,phase-data,             NaN
# 1      ...                                ,origin,phase-data,            38.0
# 2      ...     ,nearby-cities,origin,phase-data,scitech-link,            22.0
# 3      ...                                ,origin,phase-data,             NaN
# 4      ...                                ,origin,phase-data,             NaN
# ...    ...                                                ...             ...
# 10174  ...                                ,origin,phase-data,             5.0
# 10175  ...  ,focal-mechanism,nearby-cities,origin,phase-da...            27.0
# 10176  ...                                ,origin,phase-data,            11.0
# 10177  ...                                ,origin,phase-data,            15.0
# 10178  ...                                ,origin,phase-data,            42.0
#
#       properties.dmin properties.rms  properties.gap  properties.magType  \
# 0                 NaN           0.85             NaN                  ml
# 1            0.119600           0.11           188.0                  md
# 2            0.501200           0.23           220.0                  ml
# 3                 NaN           0.93             NaN                  ml
# 4                 NaN           0.78             NaN                  ml
# ...               ...            ...             ...                 ...
# 10174        0.060290           0.07           268.0                  ml
# 10175        0.041800           0.09            86.0                  ml
# 10176        0.031000           0.11            93.0                  md
# 10177        0.230355           0.39           145.0                  ml
# 10178        0.436414           0.43            89.0                  ml
#
#       properties.type                                   properties.title  \
# 0          earthquake                M 1.1 - 13 km N of Fishhook, Alaska
# 1          earthquake                 M 2.4 - 2 km WSW of Pāhala, Hawaii
# 2          earthquake               M 2.7 - 12 km WSW of Delta, B.C., MX
# 3          earthquake               M 2.1 - 73 km SE of Cantwell, Alaska
# 4          earthquake                 M 3.2 - 26 km W of Chenega, Alaska
# ...               ...                                                ...
# 10174      earthquake              M 1.6 - 73 km WSW of Nikolski, Alaska
# 10175      earthquake                         M 0.7 - 8 km N of Anza, CA
# 10176      earthquake                 M 1.6 - 5 km NNE of Pāhala, Hawaii
# 10177    quarry blast  M 1.1 Quarry Blast - 3 km SSE of Mill Creek, O...
# 10178    quarry blast  M 1.7 Quarry Blast - 2 km ESE of Rocky Mountai...
#
#       geometry.type                               geometry.coordinates
# 0             Point                        [-149.2821, 61.8655, 180.4]
# 1             Point  [-155.49983215332, 19.1961669921875, 32.590000...
# 2             Point                    [-115.303833, 32.2966652, 7.46]
# 3             Point                         [-147.8545, 62.9508, 11.3]
# 4             Point                           [-148.4755, 60.108, 8.6]
# ...             ...                                                ...
# 10174         Point       [-169.895166666667, 52.7368333333333, -1.07]
# 10175         Point                      [-116.6728333, 33.627, 14.25]
# 10176         Point       [-155.466166666667, 19.2481666666667, 33.67]
# 10177         Point                     [-96.81083333, 34.37583333, 0]
# 10178         Point                          [-94.737, 35.79966667, 0]
#
# [10179 rows x 30 columns]

# %% [markdown]
# # **Data Enrichment**

# %%
#| label: cell-dataenrichment
df_new = df.copy()
df_new.head()
# Out:
#       type            id  properties.mag              properties.place  \
# 0  Feature  ak0247l6gx1g            1.10   13 km N of Fishhook, Alaska
# 1  Feature    hv74275801            2.36    2 km WSW of Pāhala, Hawaii
# 2  Feature    ci40797520            2.68  12 km WSW of Delta, B.C., MX
# 3  Feature  ak0247l63lv6            2.10  73 km SE of Cantwell, Alaska
# 4  Feature  ak0247l63fcl            3.20    26 km W of Chenega, Alaska
#
#    properties.time  properties.updated properties.tz  \
# 0    1718302410679       1718302585284          None
# 1    1718302194290       1718302323380          None
# 2    1718301998380       1718302126916          None
# 3    1718301080508       1718301218013          None
# 4    1718301037287       1718302752417          None
#
#                                       properties.url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                    properties.detail  properties.felt  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
#
#                                  properties.types  properties.nst  \
# 0                             ,origin,phase-data,             NaN
# 1                             ,origin,phase-data,            38.0
# 2  ,nearby-cities,origin,phase-data,scitech-link,            22.0
# 3                             ,origin,phase-data,             NaN
# 4                             ,origin,phase-data,             NaN
#
#   properties.dmin properties.rms  properties.gap  properties.magType  \
# 0             NaN           0.85             NaN                  ml
# 1          0.1196           0.11           188.0                  md
# 2          0.5012           0.23           220.0                  ml
# 3             NaN           0.93             NaN                  ml
# 4             NaN           0.78             NaN                  ml
#
#   properties.type                      properties.title geometry.type  \
# 0      earthquake   M 1.1 - 13 km N of Fishhook, Alaska         Point
# 1      earthquake    M 2.4 - 2 km WSW of Pāhala, Hawaii         Point
# 2      earthquake  M 2.7 - 12 km WSW of Delta, B.C., MX         Point
# 3      earthquake  M 2.1 - 73 km SE of Cantwell, Alaska         Point
# 4      earthquake    M 3.2 - 26 km W of Chenega, Alaska         Point
#
#                                 geometry.coordinates
# 0                        [-149.2821, 61.8655, 180.4]
# 1  [-155.49983215332, 19.1961669921875, 32.590000...
# 2                    [-115.303833, 32.2966652, 7.46]
# 3                         [-147.8545, 62.9508, 11.3]
# 4                           [-148.4755, 60.108, 8.6]
#
# [5 rows x 30 columns]

# %%
#| label: cell-dataenrichment1
df_new['properties.time'] = pd.to_datetime(df_new['properties.time'], unit='ms')

# %%
#| label: cell-dataenrichment2
df_new['properties.updated'] = pd.to_datetime(df_new['properties.updated'], unit='ms')

# %%
#| label: cell-dataenrichment3
df_new.head()
# Out:
#       type            id  properties.mag              properties.place  \
# 0  Feature  ak0247l6gx1g            1.10   13 km N of Fishhook, Alaska
# 1  Feature    hv74275801            2.36    2 km WSW of Pāhala, Hawaii
# 2  Feature    ci40797520            2.68  12 km WSW of Delta, B.C., MX
# 3  Feature  ak0247l63lv6            2.10  73 km SE of Cantwell, Alaska
# 4  Feature  ak0247l63fcl            3.20    26 km W of Chenega, Alaska
#
#           properties.time      properties.updated properties.tz  \
# 0 2024-06-13 18:13:30.679 2024-06-13 18:16:25.284          None
# 1 2024-06-13 18:09:54.290 2024-06-13 18:12:03.380          None
# 2 2024-06-13 18:06:38.380 2024-06-13 18:08:46.916          None
# 3 2024-06-13 17:51:20.508 2024-06-13 17:53:38.013          None
# 4 2024-06-13 17:50:37.287 2024-06-13 18:19:12.417          None
#
#                                       properties.url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                    properties.detail  properties.felt  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
#
#                                  properties.types  properties.nst  \
# 0                             ,origin,phase-data,             NaN
# 1                             ,origin,phase-data,            38.0
# 2  ,nearby-cities,origin,phase-data,scitech-link,            22.0
# 3                             ,origin,phase-data,             NaN
# 4                             ,origin,phase-data,             NaN
#
#   properties.dmin properties.rms  properties.gap  properties.magType  \
# 0             NaN           0.85             NaN                  ml
# 1          0.1196           0.11           188.0                  md
# 2          0.5012           0.23           220.0                  ml
# 3             NaN           0.93             NaN                  ml
# 4             NaN           0.78             NaN                  ml
#
#   properties.type                      properties.title geometry.type  \
# 0      earthquake   M 1.1 - 13 km N of Fishhook, Alaska         Point
# 1      earthquake    M 2.4 - 2 km WSW of Pāhala, Hawaii         Point
# 2      earthquake  M 2.7 - 12 km WSW of Delta, B.C., MX         Point
# 3      earthquake  M 2.1 - 73 km SE of Cantwell, Alaska         Point
# 4      earthquake    M 3.2 - 26 km W of Chenega, Alaska         Point
#
#                                 geometry.coordinates
# 0                        [-149.2821, 61.8655, 180.4]
# 1  [-155.49983215332, 19.1961669921875, 32.590000...
# 2                    [-115.303833, 32.2966652, 7.46]
# 3                         [-147.8545, 62.9508, 11.3]
# 4                           [-148.4755, 60.108, 8.6]
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Extract Longitude, latitude and date data from pd

# %%
#| label: cell-dataenrichment4
# Split 'geometry.coordinates' into separate columns for longitude and latitude
df_new[['longitude', 'latitude', 'altitude']] = pd.DataFrame(df_new['geometry.coordinates'].tolist()).copy()

# Extract date from 'properties.time'
df_new['date'] = pd.to_datetime(df_new['properties.time']).dt.date.copy()
df_new['time'] = pd.to_datetime(df_new['properties.time']).dt.time.copy()

# %%
#| label: cell-dataenrichment5
# Extract 'longitude', 'latitude', and 'date' from df_new_filtered
data_list = df_new[['longitude', 'latitude', 'date']].values.tolist()

# %%
#| label: cell-dataenrichment6
data_list[10]
# Out:
# [-176.6682, -22.8177, datetime.date(2024, 6, 13)]

# %% [markdown]
# ### **Getting Data from sunrisesunset.io api**

# %%
#| label: cell-dataenrichment7
import aiohttp
import asyncio

# Function to fetch sunrise and sunset data from the API asynchronously
async def fetch_sunrise_sunset_async(session, longitude, latitude, date):
    url = f"https://api.sunrisesunset.io/json?lat={latitude}&lng={longitude}&date={date}"
    try:
        async with session.get(url) as response:
            data = await response.json()
            if data:
                data['longitude'] = longitude
                data['latitude'] = latitude
            return data
    except Exception as e:
        print("Error fetching sunrise/sunset data:", e)
        return None

async def fetch_sunrise_sunset_batch_async(entries):
    api_data_batch = []
    async with aiohttp.ClientSession() as session:
        tasks = [fetch_sunrise_sunset_async(session, *entry) for entry in entries]
        api_data_batch = await asyncio.gather(*tasks)
    return api_data_batch

batch_size = 500

api_data_list = []
for i in range(0, len(data_list), batch_size):
    batch = data_list[i:i+batch_size]
    api_data_batch = await fetch_sunrise_sunset_batch_async(batch)
    api_data_list.extend(api_data_batch)

# %%
#| label: cell-dataenrichment8
print(len(api_data_list))
# Out:
# 10179

# %%
#| label: cell-dataenrichment9
api_data_df = pd.DataFrame(api_data_list)
results_df = pd.json_normalize(api_data_df['results'])
api_data_df = pd.concat([api_data_df.drop(columns=['results']), results_df], axis=1)

# %%
#| label: cell-dataenrichment10
api_data_df.head()
# Out:
#   status   longitude   latitude        date     sunrise       sunset  \
# 0     OK -149.282100  61.865500  2024-06-13  4:12:02 AM  11:44:57 PM
# 1     OK -155.499832  19.196167  2024-06-13  5:45:09 AM   7:01:35 PM
# 2     OK -115.303833  32.296665  2024-06-13  5:35:14 AM   7:49:53 PM
# 3     OK -147.854500  62.950800  2024-06-13  3:49:02 AM  11:56:31 PM
# 4     OK -148.475500  60.108000  2024-06-13  4:31:13 AM  11:19:18 PM
#
#   first_light  last_light        dawn        dusk   solar_noon  golden_hour  \
# 0        None        None        None        None   1:58:29 PM  10:14:47 PM
# 1  4:21:59 AM  8:24:45 PM  5:20:48 AM  7:25:56 PM  12:23:22 PM   6:29:58 PM
# 2  3:54:45 AM  9:30:22 PM  5:06:54 AM  8:18:13 PM  12:42:33 PM   7:13:53 PM
# 3        None        None        None        None   1:52:47 PM  10:17:11 PM
# 4        None        None  2:47:56 AM  1:02:35 AM   1:55:16 PM   9:59:52 PM
#
#   day_length           timezone  utc_offset
# 0   19:32:55  America/Anchorage        -480
# 1   13:16:25   Pacific/Honolulu        -600
# 2   14:14:38    America/Tijuana        -420
# 3   20:07:29  America/Anchorage        -480
# 4   18:48:04  America/Anchorage        -480

# %% [markdown]
# ### Merging both dataframes

# %%
#| label: cell-dataenrichment11
# Convert 'date' column to datetime format in both DataFrames
df_new['date'] = pd.to_datetime(df_new['date'])
api_data_df['date'] = pd.to_datetime(api_data_df['date'])

# %%
#| label: cell-dataenrichment12
# Merge df_new_filtered with api_data_df on 'longitude', 'latitude', and 'date'
merged_data = pd.merge(df_new, api_data_df, 
                       on=['longitude', 'latitude', 'date'], 
                       how='inner')

# %%
#| label: cell-dataenrichment13
merged_data
# Out:
#           type            id  properties.mag  \
# 0      Feature  ak0247l6gx1g            1.10
# 1      Feature    hv74275801            2.36
# 2      Feature    ci40797520            2.68
# 3      Feature  ak0247l63lv6            2.10
# 4      Feature  ak0247l63fcl            3.20
# ...        ...           ...             ...
# 10190  Feature    av93126556            1.56
# 10191  Feature    ci40582351            0.70
# 10192  Feature    hv74230877            1.60
# 10193  Feature    ok2024jmgh            1.11
# 10194  Feature    ok2024jmgf            1.67
#
#                            properties.place         properties.time  \
# 0               13 km N of Fishhook, Alaska 2024-06-13 18:13:30.679
# 1                2 km WSW of Pāhala, Hawaii 2024-06-13 18:09:54.290
# 2              12 km WSW of Delta, B.C., MX 2024-06-13 18:06:38.380
# 3              73 km SE of Cantwell, Alaska 2024-06-13 17:51:20.508
# 4                26 km W of Chenega, Alaska 2024-06-13 17:50:37.287
# ...                                     ...                     ...
# 10190         73 km WSW of Nikolski, Alaska 2024-05-14 18:43:48.980
# 10191                    8 km N of Anza, CA 2024-05-14 18:39:54.330
# 10192            5 km NNE of Pāhala, Hawaii 2024-05-14 18:37:53.890
# 10193      3 km SSE of Mill Creek, Oklahoma 2024-05-14 18:37:19.429
# 10194  2 km ESE of Rocky Mountain, Oklahoma 2024-05-14 18:36:01.800
#
#            properties.updated properties.tz  \
# 0     2024-06-13 18:16:25.284          None
# 1     2024-06-13 18:12:03.380          None
# 2     2024-06-13 18:08:46.916          None
# 3     2024-06-13 17:53:38.013          None
# 4     2024-06-13 18:19:12.417          None
# ...                       ...           ...
# 10190 2024-05-15 23:51:15.320          None
# 10191 2024-05-14 21:24:34.210          None
# 10192 2024-05-15 01:31:24.390          None
# 10193 2024-05-15 16:40:12.738          None
# 10194 2024-05-14 20:20:52.630          None
#
#                                           properties.url  \
# 0      https://earthquake.usgs.gov/earthquakes/eventp...
# 1      https://earthquake.usgs.gov/earthquakes/eventp...
# 2      https://earthquake.usgs.gov/earthquakes/eventp...
# 3      https://earthquake.usgs.gov/earthquakes/eventp...
# 4      https://earthquake.usgs.gov/earthquakes/eventp...
# ...                                                  ...
# 10190  https://earthquake.usgs.gov/earthquakes/eventp...
# 10191  https://earthquake.usgs.gov/earthquakes/eventp...
# 10192  https://earthquake.usgs.gov/earthquakes/eventp...
# 10193  https://earthquake.usgs.gov/earthquakes/eventp...
# 10194  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                        properties.detail  properties.felt  \
# 0      https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 1      https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 2      https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 3      https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 4      https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# ...                                                  ...              ...
# 10190  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10191  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10192  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10193  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10194  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
#
#        ...       sunset  first_light  last_light        dawn         dusk  \
# 0      ...  11:44:57 PM         None        None        None         None
# 1      ...   7:01:35 PM   4:21:59 AM  8:24:45 PM  5:20:48 AM   7:25:56 PM
# 2      ...   7:49:53 PM   3:54:45 AM  9:30:22 PM  5:06:54 AM   8:18:13 PM
# 3      ...  11:56:31 PM         None        None        None         None
# 4      ...  11:19:18 PM         None        None  2:47:56 AM   1:02:35 AM
# ...    ...          ...          ...         ...         ...          ...
# 10190  ...  10:08:45 PM   3:02:35 AM  1:31:59 AM  5:42:47 AM  10:51:47 PM
# 10191  ...   7:40:20 PM   4:12:41 AM  9:16:07 PM  5:21:04 AM   8:07:43 PM
# 10192  ...   6:50:17 PM   4:29:20 AM  8:09:49 PM  5:25:24 AM   7:13:44 PM
# 10193  ...   8:22:23 PM   4:50:25 AM  9:59:28 PM  5:59:49 AM   8:50:05 PM
# 10194  ...   8:17:07 PM   4:36:23 AM  9:56:55 PM  5:47:52 AM   8:45:26 PM
#
#         solar_noon  golden_hour day_length             timezone utc_offset
# 0       1:58:29 PM  10:14:47 PM   19:32:55    America/Anchorage       -480
# 1      12:23:22 PM   6:29:58 PM   13:16:25     Pacific/Honolulu       -600
# 2      12:42:33 PM   7:13:53 PM   14:14:38      America/Tijuana       -420
# 3       1:52:47 PM  10:17:11 PM   20:07:29    America/Anchorage       -480
# 4       1:55:16 PM   9:59:52 PM   18:48:04    America/Anchorage       -480
# ...            ...          ...        ...                  ...        ...
# 10190   2:17:17 PM   9:17:33 PM   15:42:55         America/Adak       -540
# 10191  12:44:24 PM   7:05:14 PM   13:51:51  America/Los_Angeles       -420
# 10192  12:19:34 PM   6:19:42 PM   13:01:25     Pacific/Honolulu       -600
# 10193   1:24:57 PM   7:46:57 PM   13:54:52      America/Chicago       -300
# 10194   1:16:39 PM   7:40:58 PM   14:00:55      America/Chicago       -300
#
# [10195 rows x 47 columns]

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# In the code below, we're cleaning the data by dropping unnecessary columns that are not required for visualizations. This is achieved using the drop function in pandas. Additionally, we're addressing duplicate rows and null values to ensure data integrity. Duplicate rows are removed using the drop_duplicates function, while null values are handled using either the dropna function to remove rows with null values or by imputing missing values with meaningful replacements. This cleaning strategy ensures that the dataset is properly prepared for further analysis and visualization.

# %%
#| label: cell-datacleaning
merged_data.dtypes
# Out:
# type                            object
# id                              object
# properties.mag                 float64
# properties.place                object
# properties.time         datetime64[ns]
# properties.updated      datetime64[ns]
# properties.tz                   object
# properties.url                  object
# properties.detail               object
# properties.felt                float64
# properties.cdi                 float64
# properties.mmi                 float64
# properties.alert                object
# properties.status               object
# properties.tsunami               int64
# properties.sig                   int64
# properties.net                  object
# properties.code                 object
# properties.ids                  object
# properties.sources              object
# properties.types                object
# properties.nst                 float64
# properties.dmin                float64
# properties.rms                 float64
# properties.gap                 float64
# properties.magType              object
# properties.type                 object
# properties.title                object
# geometry.type                   object
# geometry.coordinates            object
# longitude                      float64
# latitude                       float64
# altitude                       float64
# date                    datetime64[ns]
# time                            object
# status                          object
# sunrise                         object
# sunset                          object
# first_light                     object
# last_light                      object
# dawn                            object
# dusk                            object
# solar_noon                      object
# golden_hour                     object
# day_length                      object
# timezone                        object
# utc_offset                       int64
# dtype: object

# %%
#| label: cell-datacleaning1
columns_to_drop = ['type', 'id', 'properties.place', 'properties.time','properties.updated','properties.felt', 'properties.alert','properties.tz','properties.cdi','properties.mmi',
                   'properties.url', 'properties.detail', 'properties.status','properties.types','properties.code', 'properties.ids','geometry.type', 
                   'geometry.coordinates','status', 'timezone', 'first_light','last_light','solar_noon','utc_offset']

merged_data = merged_data.drop(columns=columns_to_drop)

# %%
#| label: cell-datacleaning2
def handle_duplicates(df):
    num_duplicates_before = df.duplicated().sum()
    df.drop_duplicates(inplace=True)
    num_duplicates_after = df.duplicated().sum()
    return df, num_duplicates_before, num_duplicates_after


merged_data, num_duplicates_before, num_duplicates_after = handle_duplicates(merged_data)
print("Number of duplicate rows before removing duplicates:", num_duplicates_before)
print("Number of duplicate rows after removing duplicates:", num_duplicates_after)
# Out:
# Number of duplicate rows before removing duplicates: 16
# Number of duplicate rows after removing duplicates: 0

# %%
#| label: cell-datacleaning3
merged_data.isnull().sum()
# Out:
# properties.mag           0
# properties.tsunami       0
# properties.sig           0
# properties.net           0
# properties.sources       0
# properties.nst        1407
# properties.dmin       1410
# properties.rms           0
# properties.gap        1407
# properties.magType       0
# properties.type          0
# properties.title         0
# longitude                0
# latitude                 0
# altitude                 0
# date                     0
# time                     0
# sunrise                 25
# sunset                  25
# dawn                   636
# dusk                   636
# golden_hour             11
# day_length               0
# dtype: int64

# %%
#| label: cell-datacleaning4
merged_data.dropna(inplace=True)

# %%
#| label: cell-datacleaning5
merged_data.isnull().sum()
# Out:
# properties.mag        0
# properties.tsunami    0
# properties.sig        0
# properties.net        0
# properties.sources    0
# properties.nst        0
# properties.dmin       0
# properties.rms        0
# properties.gap        0
# properties.magType    0
# properties.type       0
# properties.title      0
# longitude             0
# latitude              0
# altitude              0
# date                  0
# time                  0
# sunrise               0
# sunset                0
# dawn                  0
# dusk                  0
# golden_hour           0
# day_length            0
# dtype: int64

# %%
#| label: cell-datacleaning6
merged_data.rename(columns={
    'properties.mag': 'Magnitude',
    'properties.tsunami': 'Tsunami_Alert',
    'properties.sig': 'Significance',
    'properties.net': 'Network',
    'properties.sources': 'Sources',
    'properties.nst': 'Number_of_Stations',
    'properties.dmin': 'Depth_Minimum',
    'properties.rms': 'Root_Mean_Square',
    'properties.gap': 'Gap',
    'properties.magType': 'Magnitude_Type',
    'properties.type': 'Event_Type',
    'properties.title': 'Event_Title'
}, inplace=True)

# %%
#| label: cell-datacleaning7
merged_data.head()
# Out:
#    Magnitude  Tsunami_Alert  Significance Network  Sources  \
# 1       2.36              0            86      hv     ,hv,
# 2       2.68              0           110      ci     ,ci,
# 5       2.50              0            96      us     ,us,
# 7       1.98              0            60      hv     ,hv,
# 9       3.04              0           144      hv  ,hv,us,
#
#    Number_of_Stations  Depth_Minimum  Root_Mean_Square    Gap Magnitude_Type  \
# 1                38.0        0.11960              0.11  188.0             md
# 2                22.0        0.50120              0.23  220.0             ml
# 5                12.0        0.12900              0.09  257.0             ml
# 7                30.0        0.05885              0.17   60.0             ml
# 9                58.0        0.04547              0.19   93.0             ml
#
#    ...   latitude altitude       date             time     sunrise  \
# 1  ...  19.196167   32.590 2024-06-13  18:09:54.290000  5:45:09 AM
# 2  ...  32.296665    7.460 2024-06-13  18:06:38.380000  5:35:14 AM
# 5  ...  20.137600   35.246 2024-06-13  17:40:08.403000  5:43:46 AM
# 7  ...  19.470667    1.470 2024-06-13  17:21:37.670000  5:44:26 AM
# 9  ...  19.341499    4.980 2024-06-13  17:18:11.710000  5:43:26 AM
#
#        sunset        dawn        dusk golden_hour day_length
# 1  7:01:35 PM  5:20:48 AM  7:25:56 PM  6:29:58 PM   13:16:25
# 2  7:49:53 PM  5:06:54 AM  8:18:13 PM  7:13:53 PM   14:14:38
# 5  7:03:56 PM  5:19:13 AM  7:28:29 PM  6:32:06 PM   13:20:09
# 7  7:01:57 PM  5:20:01 AM  7:26:21 PM  6:30:16 PM   13:17:30
# 9  7:00:26 PM  5:19:02 AM  7:24:49 PM  6:28:47 PM   13:16:59
#
# [5 rows x 23 columns]

# %% [markdown]
# # **Test data quality**

# %% [markdown]
# To ensure the quality and integrity of our data, we implemented a series of tests and sanity checks. Firstly, we verified the absence of missing values in the tidied DataFrame using assert statements, confirming that no data was missing. Additionally, we conducted tests to ensure a reasonable number of rows in the DataFrame and to catch any potential data processing issues or errors. Furthermore, we checked for duplicate rows to maintain data integrity and tidiness, confirming that there were no duplicate entries. These tests were crucial in ensuring the reliability of our data for subsequent analysis and visualization.

# %%
#| label: cell-dataquality
# Verify no missing values
assert merged_data.isnull().sum().sum() == 0, "There are missing values in the tidied DataFrame."

# Verify reasonable number of rows
assert len(merged_data) > 0, "The tidied DataFrame is empty."
assert len(merged_data) < 10000, "The number of rows in the tidied DataFrame seems too large. Check if there's a data processing issue."

# Check for duplicates
assert len(merged_data) == len(merged_data.drop_duplicates()), "Duplicate rows exist in the tidied DataFrame."

# %% [markdown]
# # **Store your data in at least 3 different formats**

# %% [markdown]
# Storing data in multiple formats, such as SQLite3 databases, CSV files, and Excel spreadsheets, offers versatility and accessibility across different platforms and use cases. SQLite3 databases provide efficient querying and manipulation capabilities, ideal for applications requiring frequent data retrieval. CSV files ensure compatibility with various tools and platforms, facilitating easy data exchange and processing. Excel spreadsheets offer advanced formatting and visualization options, suitable for creating reports and dashboards. By employing these formats, we enhance data accessibility, interoperability, and usability, catering to diverse user preferences and requirements in data analysis, visualization, and reporting workflows.

# %%
#| label: cell-datastore
# Save as CSV
merged_data.to_csv('cleaned_data.csv', index=False)

# %%
#| label: cell-datastore1
# Save as Excel
merged_data.to_excel('cleaned_data.xlsx', index=False)

# %%
#| label: cell-datastore2
import sqlite3
conn = sqlite3.connect('merged_data.db')
merged_data.to_sql('merged_data_table', conn, index=False, if_exists='replace')
conn.commit()
conn.close()

print("Data successfully stored in SQLite database.")
# Out:
# Data successfully stored in SQLite database.

# %% [markdown]
# # **Computation of meaningful summary statistics**

# %% [markdown]
# The summary statistics reveal key insights into the earthquake dataset for the month of April 2024. The mean earthquake magnitude is approximately 1.59, with a minimum magnitude of -1.56 and a maximum magnitude of 7.4. Around 0.12% of earthquakes triggered tsunami alerts. The significance of earthquakes ranges from 0 to 1373, with a mean of 70.96. On average, earthquakes were reported by 24.36 stations, with a maximum of 326 stations reporting for a single event. The depth of earthquakes varies widely, with a mean depth of approximately 0.49 and a maximum depth of 26.16 kilometers. The root mean square values range from 0 to 1.61, with a mean of 0.21. Gaps in data collection have a mean duration of 110.97 minutes. The dataset spans from March 29, 2024, to April 28, 2024, with a total of 8145 observations. These statistics provide a comprehensive overview of earthquake characteristics, aiding in risk assessment and disaster management efforts.

# %%
#| label: cell-datastatistics
# Summary statistics for numerical columns
summary_stats = merged_data.describe()

print("Summary Statistics:")
print(summary_stats)
# Out:
# Summary Statistics:
#          Magnitude  Tsunami_Alert  Significance  Number_of_Stations  \
# count  8717.000000    8717.000000   8717.000000         8717.000000
# mean      1.527888       0.000459     62.615235           23.091775
# min      -1.590000       0.000000      0.000000            0.000000
# 25%       0.720000       0.000000      8.000000            9.000000
# 50%       1.260000       0.000000     24.000000           17.000000
# 75%       2.010000       0.000000     62.000000           29.000000
# max       6.600000       1.000000    676.000000          303.000000
# std       1.308974       0.021418     96.338349           21.993064
#
#        Depth_Minimum  Root_Mean_Square          Gap    longitude     latitude  \
# count    8717.000000       8717.000000  8717.000000  8717.000000  8717.000000
# mean        0.464777          0.200233   110.679212  -105.496385    33.604583
# min         0.000000          0.000000    14.000000  -179.977700   -63.526100
# 25%         0.010900          0.080000    64.000000  -124.792000    31.642000
# 50%         0.040430          0.134400    91.000000  -119.580333    36.635100
# 75%         0.103200          0.220000   140.000000  -112.900833    38.845500
# max        39.923000          1.770000   352.000000   179.996500    62.806300
# std         2.080920          0.220290    65.387395    73.517438    17.088972
#
#           altitude                           date
# count  8717.000000                           8717
# mean     16.723631  2024-05-29 00:26:15.955030272
# min      -3.400000            2024-05-14 00:00:00
# 25%       2.220000            2024-05-21 00:00:00
# 50%       6.050000            2024-05-29 00:00:00
# 75%      10.280000            2024-06-05 00:00:00
# max     622.143000            2024-06-13 00:00:00
# std      53.430993                            NaN

# %%
#| label: cell-datastatistics1
# Frequency of Tsunami_Alert occurrences
tsunami_alert_freq = merged_data['Tsunami_Alert'].value_counts()

print("\nFrequency of Tsunami Alerts:")
print(tsunami_alert_freq)
# Out:
# Frequency of Tsunami Alerts:
# Tsunami_Alert
# 0    8713
# 1       4
# Name: count, dtype: int64

# %%
#| label: cell-datastatistics2
# Distribution of Magnitude_Type
magnitude_type_dist = merged_data['Magnitude_Type'].value_counts()

print("\nDistribution of Magnitude Types:")
print(magnitude_type_dist)
# Out:
# Distribution of Magnitude Types:
# Magnitude_Type
# ml       4951
# md       2847
# mb        771
# mww        76
# mwr        30
# mw         17
# mh         12
# mb_lg      12
# mlr         1
# Name: count, dtype: int64

# %% [markdown]
# # **Data Analysis**

# %%
#| label: cell-dataanalysis
numeric_columns = merged_data.select_dtypes(include=['number'])
correlation_matrix = numeric_columns.corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                     Magnitude  Tsunami_Alert  Significance  \
# Magnitude            1.000000       0.068910      0.923737
# Tsunami_Alert        0.068910       1.000000      0.114465
# Significance         0.923737       0.114465      1.000000
# Number_of_Stations   0.548993       0.181858      0.558708
# Depth_Minimum        0.464219       0.022270      0.546985
# Root_Mean_Square     0.726014       0.041317      0.802140
# Gap                 -0.131619      -0.025783     -0.064189
# longitude            0.481311       0.009334      0.547237
# latitude            -0.716961      -0.026887     -0.674686
# altitude             0.416432       0.012199      0.461549
#
#                     Number_of_Stations  Depth_Minimum  Root_Mean_Square  \
# Magnitude                     0.548993       0.464219          0.726014
# Tsunami_Alert                 0.181858       0.022270          0.041317
# Significance                  0.558708       0.546985          0.802140
# Number_of_Stations            1.000000       0.241039          0.425551
# Depth_Minimum                 0.241039       1.000000          0.468213
# Root_Mean_Square              0.425551       0.468213          1.000000
# Gap                          -0.387524      -0.000251          0.001550
# longitude                     0.252256       0.318636          0.499820
# latitude                     -0.364167      -0.466540         -0.517602
# altitude                      0.253688       0.215005          0.407498
#
#                          Gap  longitude  latitude  altitude
# Magnitude          -0.131619   0.481311 -0.716961  0.416432
# Tsunami_Alert      -0.025783   0.009334 -0.026887  0.012199
# Significance       -0.064189   0.547237 -0.674686  0.461549
# Number_of_Stations -0.387524   0.252256 -0.364167  0.253688
# Depth_Minimum      -0.000251   0.318636 -0.466540  0.215005
# Root_Mean_Square    0.001550   0.499820 -0.517602  0.407498
# Gap                 1.000000   0.073828  0.191995 -0.016584
# longitude           0.073828   1.000000 -0.264165  0.217816
# latitude            0.191995  -0.264165  1.000000 -0.406617
# altitude           -0.016584   0.217816 -0.406617  1.000000

# %%
#| label: cell-dataanalysis1
# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Based on the correlation coefficient of -0.657 between latitude and magnitude, there appears to be a moderate negative correlation between latitude and magnitude of earthquakes. This suggests that, in general, earthquakes with higher magnitudes tend to occur closer to the equator (lower latitudes), while earthquakes with lower magnitudes tend to occur farther from the equator (higher latitudes). However, it's important to note that correlation does not imply causation, and other factors may also influence the relationship between latitude and earthquake magnitude.

# %%
#| label: cell-dataanalysis2
from PIL import Image
from IPython.display import display

image_path = r"./images/General-distribution-of-world-earthquakes-along-latitudes-and-longitudes.jpg"
image = Image.open(image_path)

# Set the desired width and height for the resized image
new_width = int(image.size[0] * 0.6)  # Reduce width by 25%
new_height = int(image.size[1] * 0.5)  # Increase height by 25%

# Resize the image
resized_image = image.resize((new_width, new_height))

# Add margin on the left side
margin_width = 80 # Set the width of the margin
shifted_image = Image.new("RGB", (resized_image.width + margin_width, resized_image.height), color="white")
shifted_image.paste(resized_image, (margin_width, 0))

# Display the shifted image
display(shifted_image)
# Out:
# <PIL.Image.Image image mode=RGB size=567x195>

# %% [markdown]
# The earthquakes are not uniformly distributed along the latitudes. Above figure provides general distribution of
# world earthquakes in different latitude and longitude ranges. It is seen that the upper hemisphere provides
# for nearly 60% of the world earthquakes. Besides, latitude range from -200
#  to +500
#  contributes to 75% of the
# world earthquakes. Also the longitude range of 900
#  – 1800
#  contributes to over 50% of total world
# earthquakes. This uneven distribution of earthquakes has some bearing on the outcome of various plots.
# When earthquakes are aligned to the cycle of ascending node to ascending node (AN-AN), they are serially
# plotted in the forward direction

# %%
#| label: cell-dataanalysis3
plt.figure(figsize=(10, 8))
plt.scatter(merged_data['longitude'], merged_data['latitude'], c=merged_data['Magnitude'], cmap='viridis', alpha=0.5)
plt.colorbar(label='Magnitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Geographic Distribution of Earthquakes')
plt.grid(True)
plt.show()

# %% [markdown]
# Earthquakes are equally as likely to occur in the morning or the evening. Many studies in the past have shown no significant correlations between the rate of earthquake occurrence and the semi-diurnal tides when using large earthquake catalogs.
#
# Several recent studies, however, have found a correlation between earth tides (caused by the position of the moon relative to the earth) and some types of earthquakes. One study, for example, concludes that during times of higher earth and ocean tides, such as during times of full or new moon, earthquakes are more likely on shallow thrust faults near the edges of continents and in (underwater) subduction zones. Lunar or solar eclipses represent, of course, special cases of full and new moon, but do not cause any special or different tidal effects from full and new moon.
#
# Earth tides (Earth's surface going up and down by a couple of centimeters) and especially ocean tides (surface of the ocean going up and down by a meter or more) raise and lower the confining pressure on shallow, dipping faults near continental edges and in subduction zones.
#
# When the confining pressure is lessened, the faults are unclamped and more likely to slip. The increased probability is a factor of ~3 during high tides. But you must stop and realize that the background probability is, in general, very low in a given place and year (fractions of a percent), so that raising this tiny probability by a factor of 3 during high tides still results in a very tiny probability.
#
# There have also been some small but significant correlations reported between the semi-diurnal tides and the rate of occurrence of aftershocks in some volcanic regions, such as Mammoth Lakes.
#
# The moon, sun, and other planets have an influence on the earth in the form of perturbations (small changes) to the gravitational field. The relative amount of influence is proportional to the objects mass, and inversely proportional to the third power of its distance from the earth.
#
# The stresses induced in the earth by an extraterrestrial mass are proportional to the gravitational field gradient dg( r ) / dr and NOT to the gravitational field g( r ). g( r ) = GMm / r^2 thus: dg( r ) / dr = -2 * g( r ) / r = -2GMm / r^3

# %% [markdown]
# ### Number of Earthquakes by Hour

# %%
#| label: cell-dataanalysis4
plot_data = merged_data.copy()
plot_data['time'] = plot_data['time'].astype(str)
plot_data['hour'] = plot_data['time'].str.split(':').str[0].astype(int)

earthquakes_by_hour = plot_data.groupby('hour').size()

plt.figure(figsize=(12, 3.5))
plt.plot(earthquakes_by_hour.index, earthquakes_by_hour.values, marker='o', linestyle='-',color='brown')
plt.title('Number of Earthquakes by Hour')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Earthquakes')
plt.xticks(range(24))
plt.grid(True)
plt.show()

# %% [markdown]
# ### Number of Earthquakes by Minute

# %%
#| label: cell-dataanalysis5
plot_data['hour'] = plot_data['time'].str.split(':').str[0].astype(int)
plot_data['minute'] = plot_data['time'].str.split(':').str[1].astype(int)

plot_data['time_minutes'] = plot_data['hour'] * 60 + plot_data['minute']

earthquakes_by_minute = plot_data.groupby('time_minutes').size()

plt.figure(figsize=(20, 6))
plt.plot(earthquakes_by_minute.index, earthquakes_by_minute.values, marker='o', linestyle='-')
plt.title('Number of Earthquakes by Minute')
plt.xlabel('Minute of the Day')
plt.ylabel('Number of Earthquakes')
plt.grid(True)
plt.show()

# %% [markdown]
# # **Data  visualizations**

# %%
#| label: cell-datavisualizations
# Histogram of earthquake magnitudes
plt.figure(figsize=(10, 6))
plt.hist(merged_data['Magnitude'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Earthquake Magnitudes')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#| label: cell-datavisualizations6
tsunami_data = merged_data[merged_data['Tsunami_Alert'] == 1]
# Density plot for Magnitude and Tsunami Alert
plt.figure(figsize=(10, 6))
sns.kdeplot(data=tsunami_data, x='Magnitude', hue='Tsunami_Alert', fill=True, palette='viridis', alpha=0.7)
plt.title('Density Plot of Magnitude with Tsunami Alert')
plt.xlabel('Magnitude')
plt.ylabel('Density')
plt.legend(title='Tsunami Alert', labels=['Tsunami'], loc='upper right')
plt.show()

# %% [markdown]
# ### Earthquake Magnitude vs Sunrise&Sunser Hour

# %%
#| label: cell-datavisualizations1
plot_data = merged_data.copy()
plot_data['sunrise'] = pd.to_datetime(plot_data['sunrise'], format='%I:%M:%S %p', errors='coerce')
plot_data['sunset'] = pd.to_datetime(plot_data['sunset'], format='%I:%M:%S %p', errors='coerce')

# Extract hour component from sunrise and sunset times
plot_data['sunrise_hour'] = plot_data['sunrise'].dt.hour
plot_data['sunset_hour'] = plot_data['sunset'].dt.hour

plt.figure(figsize=(11,5))

plt.subplot(1, 2, 1)
plt.scatter(plot_data['sunrise_hour'], plot_data['Magnitude'], color='blue', alpha=0.5)
plt.title('Earthquake Magnitude vs Sunrise Hour')
plt.xlabel('Sunrise Hour')
plt.ylabel('Magnitude')

plt.subplot(1, 2, 2)
plt.scatter(plot_data['sunset_hour'], plot_data['Magnitude'], color='red', alpha=0.5)
plt.title('Earthquake Magnitude vs Sunset Hour')
plt.xlabel('Sunset Hour')
plt.ylabel('Magnitude')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Earthquake Magnitude vs Sunrise&Sunser Hour - Violin Plot

# %%
#| label: cell-datavisualizations7
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"
sns.set(style="whitegrid")

# Plot for sunrise hour
fig_sunrise = px.violin(plot_data, x='sunrise_hour', y='Magnitude', color='sunrise_hour', 
                        title='Distribution of Earthquake Magnitude by Sunrise Hour',
                        labels={'sunrise_hour': 'Sunrise Hour', 'Magnitude': 'Magnitude'},
                        violinmode='overlay', box=True)

# Plot for sunset hour
fig_sunset = px.violin(plot_data, x='sunset_hour', y='Magnitude', color='sunset_hour', 
                       title='Distribution of Earthquake Magnitude by Sunset Hour',
                       labels={'sunset_hour': 'Sunset Hour', 'Magnitude': 'Magnitude'},
                       violinmode='overlay', box=True)

# Update layout
fig_sunrise.update_layout(template="plotly_white")
fig_sunset.update_layout(template="plotly_white")
    
# Increase size of y-axis
fig_sunrise.update_yaxes(range=[-2, 8])  # Adjust the range as needed
fig_sunset.update_yaxes(range=[-2, 8])   # Adjust the range as needed

# Show plots
fig_sunrise.show()
fig_sunset.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.31.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#| label: cell-datavisualizations2
import matplotlib.animation as animation
from IPython.display import HTML


merged_data_filtered = merged_data[merged_data['Significance'] > 500]
merged_data_sorted = merged_data_filtered.sort_values(by=['date', 'time'])

def update(frame):
    merged_data_subset = merged_data_sorted.iloc[:frame+1].copy()  # Select data up to current frame
    plt.scatter(merged_data_subset['date'], merged_data_subset['Significance'], c='blue', marker='o', alpha=0.7)
    plt.xlabel('Time')
    plt.ylabel('Significance')
    plt.title('Significance of Earthquakes Over Time')
    plt.xticks(rotation=45)
    plt.tight_layout()

fig = plt.figure(figsize=(12, 6)) 
ani = animation.FuncAnimation(plt.gcf(), update, frames=len(merged_data_sorted), interval=100, repeat=False)

HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge4ebd0a282bf40548e13c693a0bc16ac">
#   <div class="anim-controls">
#     <input id="_anim_slidere4ebd0a282bf40548e13c693a0bc16ac" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime4ebd0a282bf40548e13c693a0bc16ac.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anime4ebd0a282bf40548e13c693a0bc16ac.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anime4ebd0a282bf40548e13c693a0bc16ac.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anime4ebd0a282bf40548e13c693a0bc16ac.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anime4ebd0a282bf40548e13c693a0bc16ac.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anime4ebd0a282bf40548e13c693a0bc16ac.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anime4ebd0a282bf40548e13c693a0bc16ac.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anime4ebd0a282bf40548e13c693a0bc16ac.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anime4ebd0a282bf40548e13c693a0bc16ac.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anime4ebd0a282bf40548e13c693a0bc16ac.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selecte4ebd0a282bf40548e13c693a0bc16ac"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e4ebd0a282bf40548e13c693a0bc16ac"
#              checked>
#       <label for="_anim_radio1_e4ebd0a282bf40548e13c693a0bc16ac">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e4ebd0a282bf40548e13c693a0bc16ac"
#              >
#       <label for="_anim_radio2_e4ebd0a282bf40548e13c693a0bc16ac">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e4ebd0a282bf40548e13c693a0bc16ac"
#              >
#       <label for="_anim_radio3_e4ebd0a282bf40548e13c693a0bc16ac">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge4ebd0a282bf40548e13c693a0bc16ac";
#     var slider_id = "_anim_slidere4ebd0a282bf40548e13c693a0bc16ac";
#     var loop_select_id = "_anim_loop_selecte4ebd0a282bf40548e13c693a0bc16ac";
#     var frames = new Array(22);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8g+/7EAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABt30lEQ

# %%
#| label: cell-datavisualizations3
import plotly.express as px
import ipywidgets as widgets

x_dropdown = widgets.Dropdown(options=merged_data.columns, description='X Axis:')
y_dropdown = widgets.Dropdown(options=merged_data.columns, description='Y Axis:')

def update_scatter_plot(x_column, y_column):
    fig = px.scatter(merged_data, x=x_column, y=y_column, title=f'{y_column} vs {x_column}')
    fig.show()

widgets.interactive(update_scatter_plot, x_column=x_dropdown, y_column=y_dropdown)
# Out:
# interactive(children=(Dropdown(description='X Axis:', options=('Magnitude', 'Tsunami_Alert', 'Significance', '…

# %%
#| label: cell-datavisualizations4
# Scatter plot between Root_Mean_Square and Depth_Minimum
plt.figure(figsize=(10, 6))
sns.scatterplot(data=merged_data, x='Root_Mean_Square', y='Depth_Minimum', hue='Magnitude', size='Significance', sizes=(20, 200), palette='viridis')
plt.title('Root Mean Square vs Depth Minimum')
plt.xlabel('Root Mean Square')
plt.ylabel('Depth Minimum')
plt.legend(title='Magnitude', loc='upper right')
plt.show()

# %% [markdown]
# The provided code generates a scatter plot to visualize the relationship between two variables, 'Root_Mean_Square' and 'Depth_Minimum', from the dataset 'merged_data'. Each data point on the plot represents an earthquake event, with the x-coordinate representing the root mean square value and the y-coordinate representing the depth minimum value. The color of each data point indicates the magnitude of the earthquake event, allowing for the identification of events with varying magnitudes. Additionally, the size of the markers reflects the significance of each earthquake event, with larger markers representing events of higher significance. This comprehensive visualization offers insights into how root mean square and depth minimum values relate to earthquake magnitude and significance, providing a holistic understanding of the dataset.

# %%
#| label: cell-datavisualizations5
# Pair plot
sns.set_palette("colorblind")
sns.pairplot(merged_data[['Root_Mean_Square', 'Depth_Minimum', 'Magnitude', 'Significance']], diag_kind='kde', markers='o')
plt.suptitle('Pair Plot of Earthquake Variables')
plt.show()

# %% [markdown]
# The pair plot provides a comprehensive overview of the relationships between earthquake variables in the merged_data dataset. Each variable, including 'Root_Mean_Square', 'Depth_Minimum', 'Magnitude', and 'Significance', is represented both individually along the diagonal and pairwise in scatter plots off the diagonal.
#
# The diagonal plots show the distribution of each variable, helping us understand their range and spread. Meanwhile, the scatter plots display the relationships between variables, enabling us to identify potential correlations or patterns.
#
# By examining these plots, we can assess the direction, strength, and nature of relationships between variables. Additionally, outliers or unusual data points that deviate from the general trend can be identified, indicating potential data errors or exceptional events.

# %% [markdown]
# # **Data Interactivewidgets**

# %%
#| label: cell-datainteractive
import folium
from branca.colormap import LinearColormap

tsunami_events = merged_data[merged_data['Tsunami_Alert'] ==1]

m = folium.Map(location=[0, 0], zoom_start=2, min_zoom=2)

colormap = LinearColormap(['green', 'yellow', 'orange', 'red'], vmin=tsunami_events['Magnitude'].min(), vmax=tsunami_events['Magnitude'].max())

for index, row in tsunami_events.iterrows():
    if row['Tsunami_Alert'] == 1:
        popup_content = f"<b>Title:</b> {row['Event_Title']}<br><b>Significance:</b> {row['Significance']}<br><b>Date:</b> {row['date']}"
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=5,
            popup=folium.Popup(popup_content, max_width=300),
            color=colormap(row['Magnitude']),
            fill=True,
            fill_color=colormap(row['Magnitude']),
            fill_opacity=0.7
        ).add_to(m)

note_html = '''
            <h3 style="font-family: Arial, sans-serif; font-weight: bold; font-size: 18px;">Tsunami due to Earthquakes</h3>
            '''
m.get_root().html.add_child(folium.Element(note_html))


# Add the colormap to the map
colormap.add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_188006b8e327f776044a8e6cd65b548b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;h3 style=&quot;font-family: Arial, sans-serif; font-weight: bold; font-size: 18px;&quot;&gt;Tsunami due to Earthquakes&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_188006b8e327f776044a8e6cd65b548b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_188006b8e327f776044a8e6cd65b548b = L.map(
#                 &quot;map_188006b8e327f776044a8e6cd65b548b&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_594cde3c5cb6a1c2e5ea8dffe3a408fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 2, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_594cde3c5cb6a1c2e5ea8dffe3a408fa.addTo(map_188006b8e327f776044a8e6cd65b548b);
#
#
#             var circle_marker_5d54d175bb22c18ee7e4cde685232e6a = L.circleMarker(
#                 [-19.4182, -174.8667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff0000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff0000ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_188006b8e327f776044a8e6cd65b548b);
#
#
#         var popup_3326b39edeb6053ac1c4e9d8328283e7 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_e27c004c7a63d75610123b0d4661e0b2 = $(`&lt;div id=&quot;html_e27c004c7a63d75610123b0d4661e0b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Title:&lt;/b&gt; M 6.6 - 68 km WNW of Fangale’ounga, Tonga&lt;br&gt;&lt;b&gt;Significance:&lt;/b&gt; 676&lt;br&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-05-26 00:00:00&lt;/div&gt;`)[0];
#                 popup_3326b39edeb6053ac1c4e9d8328283e7.setContent(html_e27c004c7a63d75610123b0d4661e0b2);
#
#
#
#         circle_marker_5d54d175bb22c18ee7e4cde685232e6a.bindPopup(popup_3326b39edeb6053ac1c4e9d8328283e7)
#         ;
#
#
#
#
#             var circle_marker_7a6b16452b0ca6b39de6fe91606d98b5 = L.circleMarker(
#                 [-17.1155, 167.8753],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff3a00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff3a00ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_188006b8e327f776044a8e6cd65b548b);
#
#
#         var popup_e238f2706fdc81ed1ab66c109403773e = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_acc3a86708f455773343f93f5e30dde6 = $(`&lt;div id=&quot;html_acc3a86708f455773343f93f5e30dde6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Title:&lt;/b&gt; M 6.3 - 83 km NW of Port-Vila, Vanuatu&lt;br&gt;&lt;b&gt;Significance:&lt;/b&gt; 619&lt;br&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-05-25 00:00:00&lt;/div&gt;`)[0];
#                 popup_e238f2706fdc81ed1ab66c109403773e.setContent(html_acc3a86708f455773343f93f5e30dde6);
#
#
#
#         circle_marker_7a6b16452b0ca6b39de6fe91606d98b5.bindPopup(popup_e238f2706fdc81ed1ab66c109403773e)
#         ;
#
#
#
#
#             var circle_marker_53d113af671a8ace44fe16446f0bbbb3 = L.circleMarker(
#                 [33.028, -116.0046667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#008000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#008000ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_188006b8e327f776044a8e6cd65b548b);
#
#
#         var popup_54ccf4f07ac6853b68ea1b23fb834025 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_d9bcfea1f77068688684753a5eb0bbaf = $(`&lt;div id=&quot;html_d9bcfea1f77068688684753a5eb0bbaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Title:&lt;/b&gt; M 4.1 - 17 km SE of Ocotillo Wells, CA&lt;br&gt;&lt;b&gt;Significance:&lt;/b&gt; 460
